# %% [markdown]
# # 💾 UD-04-720 데이터 저장과 EDA
#
# 수집한 데이터를 Pandas DataFrame으로 만들고, CSV 파일로 저장하는 핵심 과정을 실습합니다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 데이터프레임 생성 (UD-04-400)
#
# 리스트 형태의 데이터를 표(Table) 구조인 DataFrame으로 변환합니다.

# %%
# 코드를 작성하세요\n

# %% [markdown]
# ## 2. CSV 파일로 저장하기
#
# 생성한 데이터를 `quotes.csv` 파일로 저장하여 엑셀에서 열 수 있게 만듭니다.

# %%
# 코드를 작성하세요\n

# %% [markdown]
# ---
#
# ## 🎯 [선택/심화] 저장된 파일 다시 읽고 간단 EDA하기
#
# 파일이 잘 저장되었는지 확인하고, 간단한 통계와 시각화를 수행합니다.

# %%
# 코드를 작성하세요\n

# %%
# 코드를 작성하세요\n

# %%
# 코드를 작성하세요\n
